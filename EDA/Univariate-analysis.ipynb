# %%
print("hello")
# Out:
# hello

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("gurgaon_properties_cleaned_v2.csv")

# %%
df.duplicated().sum()
# Out:
# np.int64(111)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3298 entries, 0 to 3408
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_type        3298 non-null   object
#  1   society              3297 non-null   object
#  2   sector               3298 non-null   object
#  3   price                3282 non-null   float64
#  4   price_per_sqft       3282 non-null   float64
#  5   area                 3282 non-null   float64
#  6   bedRoom              3298 non-null   int64
#  7   bathroom             3298 non-null   int64
#  8   balcony              3298 non-null   object
#  9   floorNum             3283 non-null   float64
#  10  facing               2443 non-null   object
#  11  agePossession        3298 non-null   object
#  12  super_built_up_area  1802 non-null   float64
#  13  built_up_area        1470 non-null   float64
#  14  carpet_area          1691 non-null   float64
# ...

# %% [markdown]
# #first column-- property type

# %%
df['property_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='property_type'>

# %% [markdown]
# observation in property- type column.
# 75% flats
# 25% houses

# %% [markdown]
# #Society

# %%
df['society'].value_counts().shape
# Out:
# (599,)

# %%
df[df['society'] != 'independent']['society'].value_counts().head(10)
# Out:
# society
# tulip violet                            75
# ss the leaf                             73
# shapoorji pallonji joyville gurugram    42
# dlf new town heights                    42
# shree vardhman victoria                 34
# smart world orchard                     32
# emaar mgf emerald floors premier        32
# dlf the ultima                          31
# paras dews                              31
# m3m woodshire                           30
# Name: count, dtype: int64

# %%
df[df['society'] != 'independent']['society'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='society'>

# %%
df['society'].isnull().sum()
# Out:
# np.int64(1)

# %% [markdown]
# Observations in society.--
# 1.-- 50% flats are in top 75 societies.
# 2. one missing value

# %% [markdown]
# Sector column

# %%
df['sector'].value_counts().shape
# Out:
# (135,)

# %%
df['sector'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='sector'>

# %% [markdown]
# price

# %%
df['price'].value_counts().shape
# Out:
# (462,)

# %%
df['price'].describe()
# Out:
# count    3282.000000
# mean        2.633038
# std         3.014798
# min         0.160000
# 25%         1.050000
# 50%         1.600000
# 75%         2.857500
# max        31.500000
# Name: price, dtype: float64

# %%
sns.histplot(df['price'],kde=True,bins=50)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(x=df['price'] , color='lightgreen')
plt.grid()

# %%
df['price'].describe()
# Out:
# count    3282.000000
# mean        2.633038
# std         3.014798
# min         0.160000
# 25%         1.050000
# 50%         1.600000
# 75%         2.857500
# max        31.500000
# Name: price, dtype: float64

# %% [markdown]
# mean-- 2.63 cr
# standard derivation- 3.01 cr
# min- 0.16 cr
# max- 31 cr

# %%
#skewness and kurotsis
skewness = df['price'].skew()
kurtosis = df['price'].kurt()

print(skewness,kurtosis)
# Out:
# 3.2979295600264753 15.079569792998491

# %%
#quantile analysis
quantiles = df['price'].quantile([0.01,0.05,0.95,0.99])

quantiles
# Out:
# 0.01     0.2800
# 0.05     0.4205
# 0.95     8.5000
# 0.99    15.5950
# Name: price, dtype: float64

# %%
# with and without log--

plt.figure(figsize=(15, 6))

# Distribution plot without log transformation
plt.subplot(1, 2, 1)
sns.histplot(df['price'], kde=True, bins=50, color='skyblue')
plt.title('Distribution of Prices (Original)')
plt.xlabel('Price (in Crores)')
plt.ylabel('Frequency')

# Distribution plot with log transformation
plt.subplot(1, 2, 2)
sns.histplot(np.log1p(df['price']), kde=True, bins=50, color='lightgreen')
plt.title('Distribution of Prices (Log Transformed)')
plt.xlabel('Log(Price)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# price-per-sqft

# %%
df['price_per_sqft'].isnull().sum()
# Out:
# np.int64(16)

# %%
df['price_per_sqft'].describe()
# Out:
# count      3282.000000
# mean      13716.551798
# std       22301.764187
# min           5.000000
# 25%        7007.000000
# 50%        9135.000000
# 75%       13923.250000
# max      600000.000000
# Name: price_per_sqft, dtype: float64

# %%
sns.histplot(x=df['price_per_sqft'],bins=50,color='skyblue',kde=True)
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='Count'>

# %%
sns.boxplot(df['price_per_sqft'],color='lightgreen')
# Out:
# <Axes: ylabel='price_per_sqft'>

# %% [markdown]
# observation--
# outliers
# right-skewed values
# 16 missing values

# %% [markdown]
# bedroom

# %%
df['bedRoom'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['bedRoom'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].value_counts(normalize=True).plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# Bathroom

# %%
df['bathroom'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['bathroom'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='bathroom'>

# %% [markdown]
# balcony

# %%
df['balcony'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['balcony'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='balcony'>

# %% [markdown]
# floornum

# %%
df['floorNum'].isnull().sum()
# Out:
# np.int64(15)

# %%
df['floorNum'].describe()
# Out:
# count    3283.000000
# mean        7.121535
# std         6.148490
# min         0.000000
# 25%         2.000000
# 50%         5.000000
# 75%        10.000000
# max        51.000000
# Name: floorNum, dtype: float64

# %%
sns.boxplot(x=df['floorNum'],color='lightgreen')
# Out:
# <Axes: xlabel='floorNum'>

# %% [markdown]
# facing

# %%
df['facing'].isnull().sum()
# Out:
# np.int64(855)

# %%
df['facing'].fillna('NA',inplace=True)
# Out:
# /tmp/ipykernel_3291/3692945726.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['facing'].fillna('NA',inplace=True)

# %%
df['facing'].value_counts()
# Out:
# facing
# NA            855
# North-East    586
# East          563
# North         354
# West          233
# South         217
# North-West    180
# South-East    164
# South-West    146
# Name: count, dtype: int64

# %% [markdown]
# AgePossession

# %%
df['agePossession'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1528
# New Property           523
# Moderately Old         505
# Undefined              254
# Under Construction     247
# Old Property           241
# Name: count, dtype: int64

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# Areas

# %%
df['super_built_up_area'].isnull().sum()
# Out:
# np.int64(1496)

# %%
df['super_built_up_area'].describe()
# Out:
# count     1802.000000
# mean      1950.256515
# std        758.500311
# min         89.000000
# 25%       1524.000000
# 50%       1852.000000
# 75%       2250.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
sns.histplot(x=df['super_built_up_area'].dropna(),kde=True,color='skyblue',bins=50)
# Out:
# <Axes: xlabel='super_built_up_area', ylabel='Count'>

# %%
df[df['super_built_up_area']>6000]
# Out:
#      property_type                      society     sector  price  \
# 382           flat       krrish provence estate  sector 53    7.5
# 1030          flat  bestech park view grand spa  sector 81    4.7
#
#       price_per_sqft     area  bedRoom  bathroom balcony  floorNum  ...  \
# 382           7500.0  10000.0        5         6      3+      23.0  ...
# 1030          6786.0   6926.0        4         4      3+      19.0  ...
#
#      super_built_up_area built_up_area  carpet_area  study room  servant room  \
# 382              10000.0           NaN          NaN           0             0
# 1030              6926.0           NaN          NaN           0             0
#
#       store room  pooja room  others  furnishing_type  luxury_score
# 382            0           0       0                1            49
# 1030           0           0       0                2           140
#
# [2 rows x 22 columns]

# %%
df.drop(index=[382,1030],inplace=True)

# %%
df[df['super_built_up_area']>6000]
# Out:
# Empty DataFrame
# Columns: [property_type, society, sector, price, price_per_sqft, area, bedRoom, bathroom, balcony, floorNum, facing, agePossession, super_built_up_area, built_up_area, carpet_area, study room, servant room, store room, pooja room, others, furnishing_type, luxury_score]
# Index: []
#
# [0 rows x 22 columns]

# %%
##builtup area

# %%
df['built_up_area'].isnull().sum()
# Out:
# np.int64(1826)

# %%
df['built_up_area'].describe()
# Out:
# count      1470.000000
# mean       2216.769560
# std        5761.748122
# min          50.000000
# 25%        1261.250000
# 50%        1744.000000
# 75%        2485.250000
# max      215517.000000
# Name: built_up_area, dtype: float64

# %%
sns.histplot(x=df['built_up_area'].dropna(),bins=50,kde=True,color='skyblue')
# Out:
# <Axes: xlabel='built_up_area', ylabel='Count'>

# %%
df[df['built_up_area']>50000]
# Out:
#      property_type      society     sector  price  price_per_sqft      area  \
# 2744         house  independent  sector 50    5.0           232.0  215517.0
#
#       bedRoom  bathroom balcony  floorNum  ... super_built_up_area  \
# 2744        6         5      3+       2.0  ...                 NaN
#
#      built_up_area  carpet_area  study room  servant room  store room  \
# 2744      215517.0          NaN           1             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 2744           1       1                2             0
#
# [1 rows x 22 columns]

# %%
df.drop(index=2744,inplace=True)

# %% [markdown]
# carpet area
#
# > Add blockquote
#
# > Add blockquote

# %%
df['carpet_area'].isnull().sum()
# Out:
# np.int64(1604)

# %%
df['carpet_area'].describe()
# Out:
# count      1691.000000
# mean       2672.041170
# std       23955.954225
# min          48.000000
# 25%         951.000000
# 50%        1350.000000
# 75%        1800.000000
# max      607936.000000
# Name: carpet_area, dtype: float64

# %%
sns.histplot(x=df['carpet_area'].dropna(),bins=50,color='skyblue',kde=True)
# Out:
# <Axes: xlabel='carpet_area', ylabel='Count'>

# %%
df[df['carpet_area']>100000]
# Out:
#      property_type                    society      sector  price  \
# 1731          flat            ramsons kshitij   sector 95   0.31
# 2563          flat      signature the roselia  sector 95a   0.45
# 2574          flat  signature global solera 2  sector 107   0.51
#
#       price_per_sqft      area  bedRoom  bathroom balcony  floorNum  ...  \
# 1731             5.0  620000.0        2         2       1       1.0  ...
# 2563             7.0  642857.0        2         2       2       2.0  ...
# 2574             9.0  566667.0        2         2       1       3.0  ...
#
#      super_built_up_area built_up_area  carpet_area  study room  servant room  \
# 1731                 NaN           NaN     607936.0           0             0
# 2563                 NaN           NaN     569243.0           0             0
# 2574                 NaN           NaN     514396.0           0             0
#
#       store room  pooja room  others  furnishing_type  luxury_score
# ...

# %%
sns.boxplot(data=df['carpet_area'].dropna(),color='lightgreen')
# Out:
# <Axes: ylabel='carpet_area'>

# %%
#additional rooms

# %%
plt.figure(figsize=(20, 12))

# Create a subplot of pie charts for each room type
for idx, room in enumerate(['study room','servant room','store room','pooja room','others'], 1):
    ax = plt.subplot(2, 3, idx)
    df[room].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, ax=ax)
    plt.title(f'Distribution of {room.title()}')
    plt.ylabel('')

plt.tight_layout()
plt.show()

# %%
#furnishing type

# %%
df['furnishing_type'].value_counts()
# Out:
# furnishing_type
# 1    2142
# 2     964
# 0     189
# Name: count, dtype: int64

# %%
df['furnishing_type'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#luxury score

# %%
df['luxury_score'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['luxury_score'].describe()
# Out:
# count    3295.000000
# mean       75.209408
# std        52.849385
# min         0.000000
# 25%        38.000000
# 50%        63.000000
# 75%       114.000000
# max       174.000000
# Name: luxury_score, dtype: float64

# %%
sns.histplot(df['luxury_score'],bins=50,color='skyblue',kde=True)
# Out:
# <Axes: xlabel='luxury_score', ylabel='Count'>

# %%
df.head()
# Out:
#   property_type                               society      sector  price  \
# 0          flat                   smart world orchard   sector 61   2.10
# 1          flat                     satya element one   sector 49   0.80
# 2          flat                vatika the seven lamps   sector 82   1.28
# 3          flat  shapoorji pallonji joyville gurugram  sector 102   1.25
# 4          flat                          tulip violet   sector 69   1.42
#
#    price_per_sqft    area  bedRoom  bathroom balcony  floorNum  ...  \
# 0         13750.0  1527.0        3         2       3       3.0  ...
# 1         11111.0   720.0        1         1       1       0.0  ...
# 2          6819.0  1877.0        3         3       3       3.0  ...
# 3          9876.0  1266.0        2         2       2       0.0  ...
# 4          8998.0  1578.0        3         3       2       8.0  ...
#
#   super_built_up_area built_up_area  carpet_area  study room  servant room  \
# ...
